# %% [markdown]
# ## Trying yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np

tickers = yf.Tickers("MSFT APPL")
msft = tickers.tickers['MSFT']

# %%
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 221000,
# ...

# %%
hist = msft.history(period="max")
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.055380    0.063524    0.055380    0.060809
# 1986-03-14 00:00:00-05:00    0.060809    0.064067    0.060809    0.062980
# 1986-03-17 00:00:00-05:00    0.062980    0.064609    0.062980    0.064067
# 1986-03-18 00:00:00-05:00    0.064067    0.064609    0.061894    0.062437
# 1986-03-19 00:00:00-05:00    0.062437    0.062980    0.060809    0.061351
# ...                               ...         ...         ...         ...
# 2022-12-19 00:00:00-05:00  244.860001  245.210007  238.710007  240.449997
# 2022-12-20 00:00:00-05:00  239.399994  242.910004  238.419998  241.800003
# 2022-12-21 00:00:00-05:00  241.690002  245.619995  240.110001  244.429993
# 2022-12-22 00:00:00-05:00  241.259995  241.990005  233.869995  238.190002
# 2022-12-23 00:00:00-05:00  236.110001  238.869995  233.942795  238.729996
#
#                                Volume  Dividends  Stock Splits
# Date
# ...

# %%
msft.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 511108200,
#  'regularMarketTime': 1671823612,
#  'gmtoffset': -18000,
#  'timezone': 'EST',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 237.631,
#  'chartPreviousClose': 0.097,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EST',
#    'start': 1671786000,
#    'end': 1671805800,
#    'gmtoffset': -18000},
#   'regular': {'timezone': 'EST',
#    'start': 1671805800,
#    'end': 1671829200,
#    'gmtoffset': -18000},
#   'post': {'timezone': 'EST',
#    'start': 1671829200,
#    'end': 1671843600,
#    'gmtoffset': -18000}},
#  'dataGranularity': '1d',
#  'range': '',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
# (dividends, splits, capital gains)
msft.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-09-21 00:00:00-04:00       0.00           2.0
# 1990-04-16 00:00:00-04:00       0.00           2.0
# 1991-06-27 00:00:00-04:00       0.00           1.5
# 1992-06-15 00:00:00-04:00       0.00           1.5
# 1994-05-23 00:00:00-04:00       0.00           2.0
# ...                              ...           ...
# 2021-11-17 00:00:00-05:00       0.62           0.0
# 2022-02-16 00:00:00-05:00       0.62           0.0
# 2022-05-18 00:00:00-04:00       0.62           0.0
# 2022-08-17 00:00:00-04:00       0.62           0.0
# 2022-11-16 00:00:00-05:00       0.68           0.0
#
# [85 rows x 2 columns]

# %%
msft.dividends
# Out:
# Date
# 2003-02-19 00:00:00-05:00    0.08
# 2003-10-15 00:00:00-04:00    0.16
# 2004-08-23 00:00:00-04:00    0.08
# 2004-11-15 00:00:00-05:00    3.08
# 2005-02-15 00:00:00-05:00    0.08
#                              ...
# 2021-11-17 00:00:00-05:00    0.62
# 2022-02-16 00:00:00-05:00    0.62
# 2022-05-18 00:00:00-04:00    0.62
# 2022-08-17 00:00:00-04:00    0.62
# 2022-11-16 00:00:00-05:00    0.68
# Name: Dividends, Length: 76, dtype: float64

# %%
msft.splits
# Out:
# Date
# 1987-09-21 00:00:00-04:00    2.0
# 1990-04-16 00:00:00-04:00    2.0
# 1991-06-27 00:00:00-04:00    1.5
# 1992-06-15 00:00:00-04:00    1.5
# 1994-05-23 00:00:00-04:00    2.0
# 1996-12-09 00:00:00-05:00    2.0
# 1998-02-23 00:00:00-05:00    2.0
# 1999-03-29 00:00:00-05:00    2.0
# 2003-02-18 00:00:00-05:00    2.0
# Name: Stock Splits, dtype: float64

# %%
msft.income_stmt
# Out:
#                                                         2022-06-30  \
# Total Revenue                                       198270000000.0
# Operating Revenue                                   198270000000.0
# Cost Of Revenue                                      62650000000.0
# Gross Profit                                        135620000000.0
# Operating Expense                                    52237000000.0
# Selling General And Administration                   27725000000.0
# General And Administrative Expense                    5900000000.0
# Other Gand A                                          5900000000.0
# Selling And Marketing Expense                        21825000000.0
# Research And Development                             24512000000.0
# Operating Income                                     83383000000.0
# Net Non Operating Interest Income Expense               31000000.0
# Interest Income Non Operating                         2094000000.0
# ...

# %%
msft.recommendations
# Out:
#                                    Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00      Argus Research            Buy                up
# 2012-03-19 14:00:00      Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00      Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00                 UBS            Buy              main
# 2012-04-20 06:18:00       Deutsche Bank            Buy              main
# ...                                 ...            ...        ...    ...
# 2022-10-26 12:58:51      Wolfe Research     Outperform              main
# 2022-10-26 13:25:50  Evercore ISI Group     Outperform              main
# 2022-10-26 13:28:29         BMO Capital     Outperform              main
# 2022-10-27 11:14:36          Rosenblatt            Buy              main
# 2022-11-02 10:29:21           Macquarie        Neutral              init
#
# [424 rows x 4 columns]

# %%
msft.calendar
# Out:
#                                     0                    1
# Earnings Date     2023-01-23 10:59:00  2023-01-27 12:00:00
# Earnings Average                 2.29                 2.29
# Earnings Low                     2.23                 2.23
# Earnings High                    2.36                 2.36
# Revenue Average           52969300000          52969300000
# Revenue Low               52389000000          52389000000
# Revenue High              53475000000          53475000000

# %%
msft.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2023-10-23 06:00:00-04:00           NaN           NaN          NaN
# 2023-07-24 06:00:00-04:00           NaN           NaN          NaN
# 2023-04-24 06:00:00-04:00           NaN           NaN          NaN
# 2023-01-23 05:00:00-05:00          2.29           NaN          NaN
# 2022-10-25 12:00:00-04:00          2.30          2.35       0.0204
# 2022-07-26 12:00:00-04:00          2.29          2.23      -0.0275
# 2022-04-26 12:00:00-04:00          2.19          2.22       0.0160
# 2022-01-25 11:00:00-05:00          2.31          2.48       0.0727
# 2021-10-26 12:00:00-04:00          2.08          2.27       0.0940
# 2021-07-27 12:00:00-04:00          1.92          2.17       0.1326
# 2021-04-27 12:00:00-04:00          1.78          2.03       0.1411
# 2021-01-26 11:00:00-05:00          1.64          2.03       0.2363

# %% [markdown]
# # Testing yf.download... it doesn't give me volume so I probably won't be uding it

# %%
data = yf.download("SPY AAPL MSFT COSM", period = "max", interval = "1d", group_by = 'ticker', prepost = True)
# https://stackoverflow.com/questions/63107594/how-to-deal-with-multi-level-column-names-downloaded-with-yfinance/63107801#63107801
# data = data.stack(level=1).rename_axis(['Date', 'Ticker']).reset_index(level=1)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
data.columns
# Out:
# MultiIndex([('COSM',      'Open'),
#             ('COSM',      'High'),
#             ('COSM',       'Low'),
#             ('COSM',     'Close'),
#             ('COSM', 'Adj Close'),
#             ('COSM',    'Volume'),
#             ( 'SPY',      'Open'),
#             ( 'SPY',      'High'),
#             ( 'SPY',       'Low'),
#             ( 'SPY',     'Close'),
#             ( 'SPY', 'Adj Close'),
#             ( 'SPY',    'Volume'),
#             ('MSFT',      'Open'),
#             ('MSFT',      'High'),
#             ('MSFT',       'Low'),
#             ('MSFT',     'Close'),
#             ('MSFT', 'Adj Close'),
#             ('MSFT',    'Volume'),
#             ('AAPL',      'Open'),
#             ('AAPL',      'High'),
#             ('AAPL',       'Low'),
#             ('AAPL',     'Close'),
#             ('AAPL', 'Adj Close'),
#             ('AAPL',    'Volume')],
#            )

# %%
data["COSM"]
# Out:
#             Open     High    Low  Close  Adj Close      Volume
# Date
# 1980-12-12   NaN      NaN    NaN    NaN        NaN         NaN
# 1980-12-15   NaN      NaN    NaN    NaN        NaN         NaN
# 1980-12-16   NaN      NaN    NaN    NaN        NaN         NaN
# 1980-12-17   NaN      NaN    NaN    NaN        NaN         NaN
# 1980-12-18   NaN      NaN    NaN    NaN        NaN         NaN
# ...          ...      ...    ...    ...        ...         ...
# 2022-12-19  9.18  10.9200  7.311   7.59       7.59  35401900.0
# 2022-12-20  6.70   9.1800  5.590   8.76       8.76  33060800.0
# 2022-12-21  8.29   9.1300  7.580   8.02       8.02  12207400.0
# 2022-12-22  7.58   7.7800  6.600   7.10       7.10   4241500.0
# 2022-12-23  6.67   6.9799  6.250   6.40       6.40   2592461.0
#
# [10599 rows x 6 columns]

# %%
data.loc["2022-12-23"]
# Out:
# COSM  Open         6.670000e+00
#       High         6.979900e+00
#       Low          6.250000e+00
#       Close        6.400000e+00
#       Adj Close    6.400000e+00
#       Volume       2.592461e+06
# SPY   Open         3.796500e+02
#       High         3.830600e+02
#       Low          3.780401e+02
#       Close        3.829100e+02
#       Adj Close    3.829100e+02
#       Volume       5.968438e+07
# MSFT  Open         2.361100e+02
#       High         2.388700e+02
#       Low          2.339428e+02
#       Close        2.387300e+02
#       Adj Close    2.387300e+02
#       Volume       2.087548e+07
# AAPL  Open         1.309200e+02
#       High         1.324100e+02
#       Low          1.296400e+02
#       Close        1.318600e+02
#       Adj Close    1.318600e+02
#       Volume       6.367405e+07
# Name: 2022-12-23 00:00:00, dtype: float64

# %%
data["COSM"].loc["2022-12-23"]
# Out:
# Open         6.670000e+00
# High         6.979900e+00
# Low          6.250000e+00
# Close        6.400000e+00
# Adj Close    6.400000e+00
# Volume       2.592461e+06
# Name: 2022-12-23 00:00:00, dtype: float64
